# %%
# %pip install python-dotenv langchain_google-generativeai
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# ERROR: Could not find a version that satisfies the requirement langchain_google-generativeai (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for langchain_google-generativeai
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from dotenv import load_dotenv
#       3 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
llm.invoke("공무원 맞춤형 복지 제도에 대해서 설명해주세요")
# Out:
# AIMessage(content='공무원 맞춤형 복지 제도(Customized Welfare System for Public Officials)는 공무원 개인의 선호와 필요에 따라 주어진 예산 범위 내에서 다양한 복지 항목을 자유롭게 선택하여 이용할 수 있도록 하는 제도입니다. 획일적인 복지 혜택에서 벗어나 개인의 복지 수요를 충족시키고 직무 만족도를 높이기 위해 도입되었습니다.\n\n주요 내용을 자세히 설명해 드리겠습니다.\n\n---\n\n### **공무원 맞춤형 복지 제도의 개요**\n\n1.  **개념:**\n    *   공무원에게 개인별로 **복지점수(Welfare Points)**를 부여하고, 공무원은 이 점수를 활용하여 사전에 정해진 복지 항목 중에서 자신이 원하는 것을 자유롭게 선택하여 이용하는 제도입니다.\n    *   일반적으로 1점당 1,000원 상당의 가치를 가집니다.\n\n2.  **도입 배경:**\n    *   **획일적 복지 제도의 한계:** 기존의 모든 공무원에게 동일하게 제공되던 복지 혜택은 개인의 다양한 수요를 충족시키지 못한다는 비판이 있었습니다.\n    *   **공무원의 삶의 질 향상:** 개인의 복지 욕구를 반영하여 삶의 질을 높이고 직무 만족도를 제고하기 위함입니다.\n    *   **사기 진작 및 생산성 향상:** 복지 혜택의 만족도를 높여 공무원의 사기를 진작하고 업무 생산성을 향상시키려는 목적이 있습니다.\n    *   **효율적인 예산 집행:** 제한된 예산 내에서 공무원들이 가장 필요로 하는 복지 항목에 집중적으로 투자할 수 있도록 합니다.\n\n### **주요 내용 및 운영 방식**\n\n1.  **복지점수 부여:**\n    *   공무원 개인에게 매년 초 복지점수가 부여됩니다. 점수는 크게 다음과 같이 구성됩니다.\n        *   **기본점수:** 모든 공무원에게 동일하게 부여되는 점수입니다.\n        *   **변동점수:**\n            *   **부양가족 점수:** 배우자, 자녀, 직계존비속 등 부양가족 수에 따라 차등 부여됩니다.\n            *   **근속 점수:** 재직 연수에 따라 부여됩니다.\n            *   **직급 점수:** 직급에 따라 차등 부여되기도 합니다.\n            *   **특정 직무 점수:** 위험하거나 특수한 직무를 수행하는 공무원에게 추가 부여될 수 있습니다.\n        *   **가산점수:** 우수 공무원 포상, 특정 정책 추진 기여 등 특별한 경우 추가로 부여될 수 있습니다.\n    *   **점수 단위 및 사용:**\n        *   대부분 1점당 1,000원의 가치를 가지며, 1점 단위로 사용할 수 있습니다.\n        *   부여된 점수는 해당 연도 내에 사용해야 하며, 사용하지 않은 점수는 연말에 자동 소멸됩니다. (일부 기관은 예외적으로 이월을 허용하기도 하나 드뭅니다.)\n\n2.  **복지 항목(선택 가능 항목):**\n    공무원들은 부여받은 점수 범위 내에서 다음 복지 항목들을 자유롭게 선택하여 이용할 수 있습니다. (기관별로 항목은 다소 상이할 수 있습니다.)\n    *   **건강관리:** 건강검진, 병원 진료비, 약값, 치과 치료, 안경 구입비, 헬스장 이용료, 스포츠용품 구입비 등\n    *   **자기계발:** 도서 구입비, 학원 수강료(외국어, 자격증 등), 온라인 강좌, 문화예술 강좌, 공연 및 전시 관람료 등\n    *   **여가활용:** 국내외 여행 경비, 숙박비, 레저 스포츠 활동비, 영화/연극/뮤지컬 관람료 등\n    *   **가정친화:** 자녀 학원비, 보육비, 부모님 효도 관광비, 가족 행사비, 상조 서비스 등\n    *   **생활안정:** 보험료(단체보험 외 개인적으로 가입한 보험), 주택 관련 비용(일부 제한적), 금융 상품(일부 제한적) 등\n\n3.  **운영 방식:**\n    *   대부분의 기관은 복지 전용 온라인 시스템(복지포털)을 통해 복지점수 부여 및 사용 내역을 관리합니다.\n    *   공무원은 복지포털에서 원하는 항목을 선택하고 결제한 후, 증빙 서류(영수증 등)를 제출하여 점수를 차감하거나 현금으로 환급받는 방식입니다.\n    *   일부 항목은 제휴 업체와 직접 연계되어 결제 시 바로 점수가 차감되기도 합니다.\n\n### **장점**\n\n*   **만족도 향상:** 개인의 필요와 선호에 따라 복지 혜택을 선택할 수 있어 만족도가 높습니다.\n*   **형평성 확보:** 부양가족, 근속연수 등 개인의 상황을 고려한 점수 부여로 복지 혜택의 형평성을 높입니다.\n*   **자율성 및 책임감 증대:** 공무원 스스로 복지 혜택을 선택하고 관리하는 과정에서 자율성과 책임감이 증대됩니다.\n*   **예산 효율성 증대:** 불필요한 복지 항목에 대한 예산 낭비를 줄이고, 공무원들이 실제로 필요로 하는 곳에 예산을 집중할 수 있습니다.\n*   **사기 진작 및 생산성 향상:** 복지 혜택에 대한 만족도가 높아져 직무 몰입도와 생산성 향상에 기여합니다.\n\n---\n\n공무원 맞춤형 복지 제도는 현대 사회의 다양한 복지 수요를 반영하고, 공무원의 직무 만족도와 사기를 높여 궁극적으로는 대국민 서비스의 질 향상에도 기여하는 중요한 제도입니다. 다만, 각 기관(중앙부처, 지자체, 교육청 등)마다 예산 규모와 정책 방향에 따라 복지점수 지급 기준, 선택 가능한 복지 항목, 세부 운영 방식 등은 다소 차이가 있을 수 있습니다.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--f9b6bf24-d329-403c-bab2-cfcbad22a9f6-0', usage_metadata={'input_tokens': 14, 'output_tokens': 2861, 'total_tokens': 2875, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1469}})
