# %%
# %pip install python-dotenv langchain_google_genai
# Out:
# Requirement already satisfied: python-dotenv in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (1.2.1)
# Collecting langchain_google_genai
#   Using cached langchain_google_genai-3.2.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain_google_genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-ai-generativelanguage<1.0.0,>=0.9.0 (from langchain_google_genai)
#   Using cached google_ai_generativelanguage-0.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain_google_genai) (1.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain_google_genai) (2.12.5)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.28.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.43.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (5.29.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (0.4.49)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.32.5)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (1.71.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (0.25.0)
# Requirement already satisfied: anyio in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (4.12.0)
# Requirement already satisfied: certifi in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: idna in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/hunchulchoi/.pyenv/versions/3.12.12/envs/inflearn-llm-application/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.9.0->langchain_google_genai) (2.5.0)
# Using cached langchain_google_genai-3.2.0-py3-none-any.whl (57 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_ai_generativelanguage-0.9.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: filetype, google-ai-generativelanguage, langchain_google_genai
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.15
#     Uninstalling google-ai-generativelanguage-0.6.15:
#       Successfully uninstalled google-ai-generativelanguage-0.6.15
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.9.0 which is incompatible.
# Successfully installed filetype-1.2.0 google-ai-generativelanguage-0.9.0 langchain_google_genai-3.2.0
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
llm.invoke("공무원 맞춤형 복지 제도에 대해서 설명해주세요")
# Out:
# AIMessage(content="공무원 맞춤형 복지 제도는 공무원 개개인의 다양한 복지 수요를 충족시키기 위해, 정해진 예산 범위 내에서 개인이 원하는 복지 항목을 자유롭게 선택하도록 하는 제도입니다. '뷔페식 복지'라고도 불리며, 공무원의 직무 만족도 향상과 사기 진작을 목표로 합니다.\n\n다음은 공무원 맞춤형 복지 제도의 주요 내용입니다.\n\n---\n\n### **공무원 맞춤형 복지 제도 설명**\n\n**1. 정의**\n공무원의 다양한 복지 욕구를 반영하여, 개인에게 부여된 복지점수(예산) 범위 내에서 사전에 정해진 복지 항목들을 자유롭게 선택하여 활용할 수 있도록 하는 유연한 복지 시스템입니다.\n\n**2. 도입 목적**\n*   **다양한 복지 욕구 충족:** 공무원 개인의 연령, 가족 구성, 건강 상태, 라이프스타일 등에 따른 상이한 복지 수요를 반영합니다.\n*   **직무 만족도 및 사기 진작:** 개인이 필요한 복지를 직접 선택함으로써 복지 혜택에 대한 만족도를 높이고, 이는 곧 직무 만족도와 업무 효율성 향상으로 이어집니다.\n*   **효율적인 복지 예산 운영:** 일률적인 복지 혜택 제공 방식보다 개인의 선택권을 존중하면서도 한정된 예산을 효율적으로 배분할 수 있습니다.\n*   **삶의 질 향상:** 공무원 개개인의 건강 증진, 자기 계발, 여가 활용 등을 지원하여 전반적인 삶의 질 향상에 기여합니다.\n\n**3. 주요 특징 및 운영 방식**\n\n*   **복지점수 부여:**\n    *   공무원 개인별로 매년 일정 복지점수(예: 1점당 1,000원)가 부여됩니다.\n    *   **기본점수:** 모든 공무원에게 공통으로 부여되는 점수입니다.\n    *   **가산점수:** 근속연수, 부양가족 수, 직급, 특수직무 수행 여부 등에 따라 추가로 부여되는 점수입니다.\n*   **복지 항목 선택:**\n    *   개인에게 부여된 복지점수 범위 내에서 사전에 제시된 복지 항목들 중 필요한 것을 선택합니다.\n    *   선택된 복지 항목에 따라 해당 점수가 차감되는 방식입니다.\n    *   대부분의 기관은 온라인 복지 시스템을 통해 복지 항목을 신청하고 관리합니다.\n*   **점수 소멸:** 대부분의 경우, 연말까지 사용하지 않은 잔여 복지점수는 이월되지 않고 소멸됩니다. (일부 기관은 예외적으로 이월을 허용하기도 하나 드뭅니다.)\n\n**4. 복지 항목의 구성 (예시)**\n\n맞춤형 복지 제도는 크게 **필수 기본 항목**과 **자율 선택 항목**으로 나눌 수 있습니다.\n\n*   **필수 기본 항목:**\n    *   공무원이라면 반드시 가입해야 하는 항목으로, 주로 안전 및 건강과 관련된 최소한의 복지를 보장합니다.\n    *   예: 생명/상해보험 가입, 단체보험 가입, 건강검진 비용 등\n\n*   **자율 선택 항목:**\n    *   필수 항목에 사용하고 남은 점수를 활용하여 개인이 자유롭게 선택할 수 있는 항목입니다.\n    *   **건강 관리:** 헬스장, 요가, 수영 등 운동 시설 이용료, 영양제, 안경/렌즈 구입, 병원비(비급여 항목) 등\n    *   **자기 계발:** 도서 구입, 학원 수강료, 온라인 강의, 자격증 취득 비용, 문화 예술 강좌 등\n    *   **여가 활용:** 국내외 여행 경비, 영화/공연/전시회 관람료, 레저 스포츠 활동비, 숙박 시설 이용료 등\n    *   **가정 생활 지원:** 보육비, 학비, 명절 선물 구입비, 생활용품 구입비, 경조사비, 부모님 효도 관광 등\n    *   **기타:** 개인 연금, 기부금 등 기관별 특성에 따라 다양한 항목이 포함될 수 있습니다.\n\n**5. 기대 효과**\n*   공무원의 만족도 및 사기 진작\n*   업무 효율성 및 생산성 증대\n*   개인의 삶의 질 향상 및 워라밸(일과 삶의 균형) 실현 지원\n*   유연하고 효율적인 복지 예산 운영\n*   우수 인재 유치 및 유지에 기여\n\n---\n\n공무원 맞춤형 복지 제도는 공무원 개개인의 다양성을 존중하고, 그들의 삶의 질 향상과 직무 만족도를 높이는 데 기여하는 중요한 복지 정책입니다. 각 기관(중앙부처, 지자체, 공공기관 등)의 예산과 정책에 따라 세부적인 복지점수 배정 방식이나 선택 가능한 항목의 범위는 다소 차이가 있을 수 있습니다.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--800fb53a-9a09-433b-8040-5df0b38a5ddc-0', usage_metadata={'input_tokens': 14, 'output_tokens': 2706, 'total_tokens': 2720, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1571}})
