# %%
# %pip install langchain-ollama

from langchain_ollama import ChatOllama

llm = ChatOllama(model="gpt-oss")
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
llm.invoke("공무원 맞춤형복지")
# Out:
# AIMessage(content='## 공무원 맞춤형복지란?  \n\n### 1. 정의  \n**공무원 맞춤형복지**는 ‘공무원 한 명 한 명의 생활·성향·가족구성·연령·직급·근무형태(정규직·계약직·연수생 등)’에 맞춰 설계·제공되는 복지 서비스를 말합니다.  \n단순히 ‘일괄적’이 아니라, 개별(또는 그룹) 맞춤형으로 설계해 직원 만족도와 업무 효율성을 동시에 높이는 것이 목표입니다.\n\n---\n\n## 2. 복지 항목별 구분  \n| 구분 | 예시 | 공무원 맞춤형 적용 예시 |\n|------|------|------------------------|\n| **금전적** | 급여·연금·복리후생 수당 | 직급·근속연수에 따른 ‘복리후생 포인트’ 제도 |\n| **비금전적** | 휴가·근무시간·재택근무 | 유연근무제, 가족·돌봄 휴가 등 |\n| **의료·건강** | 건강검진·치료비 지원 | 직급·연령·성별에 따라 차등 적용 (예: 노인·신체계약자) |\n| **교육·개발** | 직무교육·자격증 취득 | 개인 역량강화 목표에 따라 맞춤형 학습 코스 제공 |\n| **가족·주거** | 자녀 교육비 지원·주택자금 | 자녀 수, 직급·연봉에 따라 차등 보조 |\n| **문화·레저** | 체육·문화비 | 직무성향·가족구성에 맞춘 프로그램(가족레저, 팀스포츠 등) |\n| **디지털/서비스** | 모바일 포털·복지앱 | 개인 선호에 따른 혜택 포인트 추천 서비스 |\n\n---\n\n## 3. 정책 배경 & 필요성  \n\n| 배경 | 내용 |\n|------|------|\n| **공무원 특성** | 장시간 근무·비정규직 비율 상승·공공서비스 품질 향상 필요 |\n| **인력 확보 경쟁** | 민간과의 연봉·복지 경쟁력 확보 |\n| **복지 효율성** | 예산 효율을 위해 ‘필요성·효과’ 기반 맞춤형 지원 |\n| **공공신뢰** | 복지 만족도가 서비스 만족·신뢰도에 직접 연결 |\n\n---\n\n## 4. 현재 적용 사례 (한국 기준)\n\n| 기관/
# ...
